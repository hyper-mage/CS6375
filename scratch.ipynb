# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# fix random seed for reproducibility
np.random.seed(1)
data = pd.read_csv('DJI.csv', usecols=['Date','Open','High','Low','Close'], engine='python')
plt.plot(data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-2f33b8139ef7> in <module>
#       5 np.random.seed(1)
#       6 data = pd.read_csv('DJI.csv', usecols=['Date','Open','High','Low','Close'], engine='python')
# ----> 7 plt.plot(data)
#       8 plt.show()
#       9
#
# c:\users\mlynn\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# c:\users\mlynn\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# ...
